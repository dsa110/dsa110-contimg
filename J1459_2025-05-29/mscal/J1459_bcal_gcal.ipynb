# %%
import casatools
import casatasks
import numpy as np
import glob, os
from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
def find_central_time_range(ms_file, fraction=0.3):
    """
    Find the central time range of an MS (corrected version)
    
    Parameters
    ----------
    ms_file : str
        Path to measurement set
    fraction : float
        Fraction of total time to use (0.3 = central 30%)
    """
    
    # Use table tool to get time information directly
    tb = casatools.table()
    
    try:
        tb.open(ms_file)
        
        # Get all times from the main table
        times = tb.getcol('TIME')
        
        # Get unique times and sort them
        unique_times = np.unique(times)
        
        tb.close()
        
        # Calculate time range
        start_time = np.min(unique_times)
        end_time = np.max(unique_times)
        total_duration = end_time - start_time
        
        # Calculate central time range
        central_duration = total_duration * fraction
        central_start = start_time + (total_duration - central_duration) / 2
        central_end = central_start + central_duration
        
        # Convert to CASA time format
        qa = casatools.quanta()
        start_time_str = qa.time(qa.quantity(start_time, 's'), form='ymd')[0]
        end_time_str = qa.time(qa.quantity(end_time, 's'), form='ymd')[0]
        central_start_str = qa.time(qa.quantity(central_start, 's'), form='ymd')[0]
        central_end_str = qa.time(qa.quantity(central_end, 's'), form='ymd')[0]
        
        print(f"MS: {ms_file}")
        print(f"Full time range: {start_time_str} to {end_time_str}")
        print(f"Total duration: {total_duration/3600:.2f} hours")
        print(f"Central {fraction*100:.0f}% time range: {central_start_str} to {central_end_str}")
        print(f"Central duration: {central_duration/3600:.2f} hours")
        print(f"Central timerange string: '{central_start_str}~{central_end_str}'")
        
        return f"{central_start_str}~{central_end_str}"
        
    except Exception as e:
        print(f"Error reading times from {ms_file}: {e}")
        
        # Fallback: try with msmetadata
        try:
            msmd = casatools.msmetadata()
            msmd.open(ms_file)
            
            # Get times using msmetadata
            time_range = msmd.timerangeforobs()
            msmd.close()
            
            # Extract start and end times
            start_time = time_range['begin']['m0']['value']
            end_time = time_range['end']['m0']['value']
            total_duration = end_time - start_time
            
            # Calculate central range
            central_duration = total_duration * fraction
            central_start = start_time + (total_duration - central_duration) / 2
            central_end = central_start + central_duration
            
            # Convert to time strings
            qa = casatools.quanta()
            central_start_str = qa.time(qa.quantity(central_start, 's'), form='ymd')[0]
            central_end_str = qa.time(qa.quantity(central_end, 's'), form='ymd')[0]
            
            print(f"Using fallback method for {ms_file}")
            print(f"Central timerange: {central_start_str}~{central_end_str}")
            
            return f"{central_start_str}~{central_end_str}"
            
        except Exception as e2:
            print(f"Fallback method also failed: {e2}")
            return None

# %%
# Test the corrected function
central_timerange = find_central_time_range('/data/jfaber/dsa110-contimg/J1459_2025-05-29/msfiles/base/J1459_250529_60min_centered.ms', fraction=0.25)
# Out:
# MS: /data/jfaber/dsa110-contimg/J1459_2025-05-29/msfiles/base/J1459_250529_60min_centered.ms
# Full time range: 2025/05/29/05:52:32 to 2025/05/29/07:00:48
# Total duration: 1.14 hours
# Central 25% time range: 2025/05/29/06:18:08 to 2025/05/29/06:35:12
# Central duration: 0.28 hours
# Central timerange string: '2025/05/29/06:18:08~2025/05/29/06:35:12'

# %%
def calibration(ms_file, cal_field_id, refant='pad103'):
    """
    More granular approach with splits at each step
    """
    
    base_name = ms_file.replace('.ms', '')
    
    print("=== STEP-BY-STEP CALIBRATION WITH SPLITS ===")
    
    # Step 1: Create a clean copy for calibration work
    print("\n1. Creating working copy...")
    working_ms = f"{base_name}_working.ms"
    
    if os.path.exists(working_ms):
        os.system(f'rm -rf {working_ms}')
    
    casatasks.split(
        vis=ms_file,
        outputvis=working_ms,
        datacolumn='data',
        keepflags=True  # Keep original flags
    )
    
    # Step 2: Initial flagging
    print("\n2. Flagging bad data...")
    casatasks.flagdata(vis=working_ms, mode='shadow', tolerance=0.0)
    casatasks.flagdata(vis=working_ms, mode='clip', clipzeros=True)
    
    # Step 3: Extract calibrator for bandpass
    print("\n3. Extracting calibrator for bandpass...")
    central_timerange = find_central_time_range(working_ms, fraction=0.3)
    
    cal_for_bp_ms = f"{base_name}_cal_for_bandpass.ms"
    if os.path.exists(cal_for_bp_ms):
        os.system(f'rm -rf {cal_for_bp_ms}')
    
    casatasks.split(
        vis=working_ms,
        outputvis=cal_for_bp_ms,
        field=str(cal_field_id),
        timerange=central_timerange,
        datacolumn='data'
    )
    
    # Step 4: Bandpass calibration
    print("\n4. Bandpass calibration...")
    bp_table = f"{base_name}_bandpass.bcal"
    
    casatasks.bandpass(
        vis=cal_for_bp_ms,
        caltable=bp_table,
        refant=refant,
        bandtype='B',
        solint='inf',
        combine='scan',
        minsnr=3.0,
        fillgaps=80
    )
    
    # Step 5: Apply bandpass and create new MS
    print("\n5. Applying bandpass...")
    bp_applied_ms = f"{base_name}_bp_applied.ms"
    
    if os.path.exists(bp_applied_ms):
        os.system(f'rm -rf {bp_applied_ms}')
    
    casatasks.applycal(
        vis=working_ms,
        gaintable=[bp_table],
        calwt=False
    )
    
    casatasks.split(
        vis=working_ms,
        outputvis=bp_applied_ms,
        datacolumn='corrected'
    )
    
    # Step 6: Gain calibration on bandpass-corrected data
    print("\n6. Gain calibration...")
    
    # Extract just calibrator from bandpass-corrected data
    cal_bp_ms = f"{base_name}_cal_bp_corrected.ms"
    if os.path.exists(cal_bp_ms):
        os.system(f'rm -rf {cal_bp_ms}')
    
    casatasks.split(
        vis=bp_applied_ms,
        outputvis=cal_bp_ms,
        field=str(cal_field_id)
    )
    
    # Phase calibration
    phase_table = f"{base_name}_phase.gcal"
    casatasks.gaincal(
        vis=cal_bp_ms,
        caltable=phase_table,
        gaintype='G',
        solint='60s',
        refant=refant,
        calmode='p',
        minsnr=3.0
    )
    
    # Amplitude calibration
    amp_table = f"{base_name}_amp.gcal"
    casatasks.gaincal(
        vis=cal_bp_ms,
        caltable=amp_table,
        gaintype='G',
        solint='60s',
        refant=refant,
        calmode='ap',
        gaintable=[phase_table],
        minsnr=3.0
    )
    
    # Step 7: Apply all calibrations and create final MS
    print("\n7. Creating final calibrated MS...")
    final_ms = f"{base_name}_final_calibrated.ms"
    
    if os.path.exists(final_ms):
        os.system(f'rm -rf {final_ms}')
    
    casatasks.applycal(
        vis=bp_applied_ms,
        gaintable=[bp_table, amp_table],
        calwt=False
    )
    
    casatasks.split(
        vis=bp_applied_ms,
        outputvis=final_ms,
        datacolumn='corrected'
    )
    
    print("\n=== FILES CREATED ===")
    print(f"Working copy: {working_ms}")
    print(f"Bandpass-corrected: {bp_applied_ms}")
    print(f"Final calibrated: {final_ms}")
    print(f"Calibration tables: {bp_table}, {phase_table}, {amp_table}")
    
    return {
        'working_ms': working_ms,
        'bp_applied_ms': bp_applied_ms,
        'final_ms': final_ms,
        'tables': [bp_table, phase_table, amp_table]
    }

# %%
# Run with correct field
ms_dict = calibration('/data/jfaber/dsa110-contimg/J1459_2025-05-29/msfiles/base/mscal/J1459_250529_60min_centered.ms', cal_field_id=117, refant='pad103')
# Out:
# === STEP-BY-STEP CALIBRATION WITH SPLITS ===
#
# 1. Creating working copy...
#
# 2. Flagging bad data...
# 2025-06-03 02:20:00	SEVERE	MeasTable::dUTC(Double) (file /source/casa6/casatools/casacore/measures/Measures/MeasTable.cc, line 4290)	Leap second table TAI_UTC seems out-of-date.
# 2025-06-03 02:20:00	SEVERE	MeasTable::dUTC(Double) (file /source/casa6/casatools/casacore/measures/Measures/MeasTable.cc, line 4290)+	Until the table is updated (see the CASA documentation or your system admin),
# 2025-06-03 02:20:00	SEVERE	MeasTable::dUTC(Double) (file /source/casa6/casatools/casacore/measures/Measures/MeasTable.cc, line 4290)+	times and coordinates derived from UTC could be wrong by 1s or more.
# 3. Extracting calibrator for bandpass...
# MS: /data/jfaber/dsa110-contimg/J1459_2025-05-29/msfiles/base/mscal/J1459_250529_60min_centered_working.ms
# Full time range: 2025/05/29/05:52:32 to 2025/05/29/07:00:48
# Total duration: 1.14 hours
# Central 30% time range: 2025/05/29/06:16:26 to 2025/05/29/06:36:55
# Central duration: 0.34 hours
# Central timerange string: '2025/05/29/06:16:26~2025/05/29/06:36:55'
#
# 4. Bandpass calibration...
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 2025-06-03 02:22:53	WARN	MSDerivedValues::parAngle	unhandled mount type
# 30 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=767) at 2025/05/29/06:24:17.7
# 31 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=766) at 2025/05/29/06:24:17.7
# 5 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=765) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=764) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=763) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=762) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=761) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=760) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=759) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=758) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=757) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=756) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=755) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=754) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=753) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=752) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=751) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=750) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=749) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=748) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=747) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=746) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=745) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=744) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=743) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=742) at 2025/05/29/06:24:17.7
# 4 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=741) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=740) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=739) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=738) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=737) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=736) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=735) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=734) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=733) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=732) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=731) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=730) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=729) at 2025/05/29/06:24:17.7
# 139 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=728) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=727) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=726) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=725) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=724) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=723) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=722) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=721) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=720) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=717) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=716) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=715) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=714) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=713) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=712) at 2025/05/29/06:24:17.7
# 44 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=711) at 2025/05/29/06:24:17.7
# 48 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=710) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=709) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=708) at 2025/05/29/06:24:17.7
# 60 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=707) at 2025/05/29/06:24:17.7
# 53 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=706) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=704) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=703) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=701) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=700) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=699) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=698) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=696) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=695) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=693) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=692) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=691) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=690) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=689) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=688) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=687) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=686) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=685) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=680) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=678) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=676) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=675) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=670) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=665) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=664) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=662) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=660) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=659) at 2025/05/29/06:24:17.7
# 12 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=657) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=654) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=647) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=645) at 2025/05/29/06:24:17.7
# 13 of 192 solutions flagged due to SNR < 3 in spw=0 (chan=639) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=637) at 2025/05/29/06:24:17.7
# 14 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=636) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=635) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=630) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=628) at 2025/05/29/06:24:17.7
# 76 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=627) at 2025/05/29/06:24:17.7
# 164 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=626) at 2025/05/29/06:24:17.7
# 166 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=625) at 2025/05/29/06:24:17.7
# 79 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=624) at 2025/05/29/06:24:17.7
# 81 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=623) at 2025/05/29/06:24:17.7
# 89 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=622) at 2025/05/29/06:24:17.7
# 90 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=621) at 2025/05/29/06:24:17.7
# 87 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=620) at 2025/05/29/06:24:17.7
# 82 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=619) at 2025/05/29/06:24:17.7
# 156 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=618) at 2025/05/29/06:24:17.7
# 160 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=617) at 2025/05/29/06:24:17.7
# 161 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=616) at 2025/05/29/06:24:17.7
# 162 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=615) at 2025/05/29/06:24:17.7
# 162 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=614) at 2025/05/29/06:24:17.7
# 165 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=613) at 2025/05/29/06:24:17.7
# 161 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=612) at 2025/05/29/06:24:17.7
# 157 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=611) at 2025/05/29/06:24:17.7
# 147 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=610) at 2025/05/29/06:24:17.7
# 144 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=609) at 2025/05/29/06:24:17.7
# 150 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=608) at 2025/05/29/06:24:17.7
# 155 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=607) at 2025/05/29/06:24:17.7
# 154 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=606) at 2025/05/29/06:24:17.7
# 155 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=605) at 2025/05/29/06:24:17.7
# 157 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=604) at 2025/05/29/06:24:17.7
# 160 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=603) at 2025/05/29/06:24:17.7
# 154 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=602) at 2025/05/29/06:24:17.7
# 161 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=601) at 2025/05/29/06:24:17.7
# 82 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=600) at 2025/05/29/06:24:17.7
# 88 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=599) at 2025/05/29/06:24:17.7
# 83 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=598) at 2025/05/29/06:24:17.7
# 80 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=597) at 2025/05/29/06:24:17.7
# 81 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=596) at 2025/05/29/06:24:17.7
# 68 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=582) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=579) at 2025/05/29/06:24:17.7
# 122 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=568) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=552) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=531) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=528) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=516) at 2025/05/29/06:24:17.7
# 155 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=494) at 2025/05/29/06:24:17.7
# 83 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=493) at 2025/05/29/06:24:17.7
# 74 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=454) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=451) at 2025/05/29/06:24:17.7
# 18 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=447) at 2025/05/29/06:24:17.7
# 88 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=384) at 2025/05/29/06:24:17.7
# 4 of 192 solutions flagged due to SNR < 3 in spw=0 (chan=383) at 2025/05/29/06:24:17.7
# 145 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=376) at 2025/05/29/06:24:17.7
# 130 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=363) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=318) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=283) at 2025/05/29/06:24:17.7
# 10 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=282) at 2025/05/29/06:24:17.7
# 6 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=281) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=280) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=279) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=278) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=277) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=276) at 2025/05/29/06:24:17.7
# 6 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=275) at 2025/05/29/06:24:17.7
# 23 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=274) at 2025/05/29/06:24:17.7
# 50 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=273) at 2025/05/29/06:24:17.7
# 52 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=272) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=271) at 2025/05/29/06:24:17.7
# 50 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=270) at 2025/05/29/06:24:17.7
# 75 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=269) at 2025/05/29/06:24:17.7
# 73 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=268) at 2025/05/29/06:24:17.7
# 74 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=267) at 2025/05/29/06:24:17.7
# 74 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=266) at 2025/05/29/06:24:17.7
# 73 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=265) at 2025/05/29/06:24:17.7
# 122 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=264) at 2025/05/29/06:24:17.7
# 82 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=263) at 2025/05/29/06:24:17.7
# 80 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=262) at 2025/05/29/06:24:17.7
# 135 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=261) at 2025/05/29/06:24:17.7
# 133 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=260) at 2025/05/29/06:24:17.7
# 143 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=259) at 2025/05/29/06:24:17.7
# 145 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=258) at 2025/05/29/06:24:17.7
# 22 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=257) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=222) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=218) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=213) at 2025/05/29/06:24:17.7
# 3 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=199) at 2025/05/29/06:24:17.7
# 138 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=198) at 2025/05/29/06:24:17.7
# 26 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=195) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=160) at 2025/05/29/06:24:17.7
# 131 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=158) at 2025/05/29/06:24:17.7
# 2 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=156) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=154) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=149) at 2025/05/29/06:24:17.7
# 148 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=142) at 2025/05/29/06:24:17.7
# 76 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=134) at 2025/05/29/06:24:17.7
# 65 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=131) at 2025/05/29/06:24:17.7
# 6 of 192 solutions flagged due to SNR < 3 in spw=0 (chan=127) at 2025/05/29/06:24:17.7
# 72 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=86) at 2025/05/29/06:24:17.7
# 75 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=85) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=84) at 2025/05/29/06:24:17.7
# 73 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=83) at 2025/05/29/06:24:17.7
# 138 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=82) at 2025/05/29/06:24:17.7
# 149 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=81) at 2025/05/29/06:24:17.7
# 153 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=80) at 2025/05/29/06:24:17.7
# 160 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=79) at 2025/05/29/06:24:17.7
# 162 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=78) at 2025/05/29/06:24:17.7
# 161 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=77) at 2025/05/29/06:24:17.7
# 161 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=76) at 2025/05/29/06:24:17.7
# 162 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=75) at 2025/05/29/06:24:17.7
# 162 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=74) at 2025/05/29/06:24:17.7
# 155 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=73) at 2025/05/29/06:24:17.7
# 159 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=72) at 2025/05/29/06:24:17.7
# 154 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=71) at 2025/05/29/06:24:17.7
# 158 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=70) at 2025/05/29/06:24:17.7
# 158 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=69) at 2025/05/29/06:24:17.7
# 153 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=68) at 2025/05/29/06:24:17.7
# 158 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=67) at 2025/05/29/06:24:17.7
# 151 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=66) at 2025/05/29/06:24:17.7
# 153 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=65) at 2025/05/29/06:24:17.7
# 139 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=64) at 2025/05/29/06:24:17.7
# 136 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=63) at 2025/05/29/06:24:17.7
# 154 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=62) at 2025/05/29/06:24:17.7
# 80 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=61) at 2025/05/29/06:24:17.7
# 77 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=60) at 2025/05/29/06:24:17.7
# 77 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=59) at 2025/05/29/06:24:17.7
# 78 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=58) at 2025/05/29/06:24:17.7
# 78 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=57) at 2025/05/29/06:24:17.7
# 81 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=56) at 2025/05/29/06:24:17.7
# 74 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=55) at 2025/05/29/06:24:17.7
# 77 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=54) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=53) at 2025/05/29/06:24:17.7
# 149 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=35) at 2025/05/29/06:24:17.7
# 146 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=24) at 2025/05/29/06:24:17.7
# 34 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=5) at 2025/05/29/06:24:17.7
# 1 of 188 solutions flagged due to SNR < 3 in spw=0 (chan=4) at 2025/05/29/06:24:17.7
#
# 5. Applying bandpass...
#
# 6. Gain calibration...
# 2025-06-03 02:29:47	WARN	MSTransformManager::checkDataColumnsToFill	CORRECTED_DATA column requested but not available in input MS
# 2025-06-03 02:29:47	SEVERE	split::::casa	Task split raised an exception of class RuntimeError with the following message: Desired column (CORRECTED_DATA) not found in the input MS (/data/jfaber/dsa110-contimg/J1459_2025-05-29/msfiles/base/mscal/J1459_250529_60min_centered_bp_applied.ms).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Run with correct field
# ----> 2 ms_dict = calibration('/data/jfaber/dsa110-contimg/J1459_2025-05-29/msfiles/base/mscal/J1459_250529_60min_centered.ms', cal_field_id=117, refant='pad103')
#
# Cell In[13], line 87, in calibration(ms_file, cal_field_id, refant)
#      84 if os.path.exists(cal_bp_ms):
#      85     os.system(f'rm -rf {cal_bp_ms}')
# ---> 87 casatasks.split(
#      88     vis=bp_applied_ms,
#      89     outputvis=cal_bp_ms,
#      90     field=str(cal_field_id)
#      91 )
#      93 # Phase calibration
#      94 phase_table = f"{base_name}_phase.gcal"
#
# File /data/jfaber/conda/envs/dsa_contimg/lib/python3.10/site-packages/casatasks/split.py:260, in _split.__call__(self, vis, outputvis, keepmms, field, spw, scan, antenna, correlation, timerange, intent, array, uvrange, observation, feed, datacolumn, keepflags, width, timebin, combine)
#     258 task_result = None
#     259 try:
# --> 260     task_result = _split_t( _pc.document['vis'], _pc.document['outputvis'], _pc.document['keepmms'], _pc.document['field'], _pc.document['spw'], _pc.document['scan'], _pc.document['antenna'], _pc.document['correlation'], _pc.document['timerange'], _pc.document['intent'], _pc.document['array'], _pc.document['uvrange'], _pc.document['observation'], _pc.document['feed'], _pc.document['datacolumn'], _pc.document['keepflags'], _pc.document['width'], _pc.document['timebin'], _pc.document['combine'] )
#     261 except Exception as exc:
#     262     _except_log('split', exc)
#
# File /data/jfaber/conda/envs/dsa_contimg/lib/python3.10/site-packages/casatasks/private/task_split.py:163, in split(vis, outputvis, keepmms, field, spw, scan, antenna, correlation, timerange, intent, array, uvrange, observation, feed, datacolumn, keepflags, width, timebin, combine)
#     160 mtlocal.config(config)
#     162 # Open the MS, select the data and configure the output
# --> 163 mtlocal.open()
#     165 # Run the tool
#     166 mtlocal.run()
#
# File /data/jfaber/conda/envs/dsa_contimg/lib/python3.10/site-packages/casatools/mstransformer.py:36, in mstransformer.open(self)
#      33 def open(self):
#      34     """It assumes that mt.config() was run before.
#      35     """
# ---> 36     return self._swigobj.open()
#
# File /data/jfaber/conda/envs/dsa_contimg/lib/python3.10/site-packages/casatools/__casac__/mstransformer.py:176, in mstransformer.open(self)
#     156 def open(self):
#     157     """
#     158     open(self) -> bool
#     159
#    (...)
#     174
#     175     """
# --> 176     return _mstransformer.mstransformer_open(self)
#
# RuntimeError: Desired column (CORRECTED_DATA) not found in the input MS (/data/jfaber/dsa110-contimg/J1459_2025-05-29/msfiles/base/mscal/J1459_250529_60min_centered_bp_applied.ms).
