# %% [markdown]
# # Test QA Notebook
#
# Generated: 2025-11-09 16:30:35

# %%
# QA Visualization Framework
from dsa110_contimg.qa.visualization import (
    FITSFile,
    CasaTable,
    ls,
    init_js9,
    render_table,
    render_status_message,
)

# Initialize JS9 for FITS viewing
init_js9()

# Standard imports
import os
from pathlib import Path

# %%
# Browse QA output directory
qa_dir = ls("/data/dsa110-contimg/state/qa")
qa_dir.show()

# Find FITS files
fits_files = qa_dir.fits
if fits_files:
    print(f"Found {len(fits_files)} FITS files")
    fits_files.show()

# %%
# Notebook complete
msg = "QA notebook generated successfully"
render_status_message(msg, message_type="success")
